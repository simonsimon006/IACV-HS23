# %% [markdown]
# # Exercise 4: Image Classification
#
#
# Given an input RGB image, you should train a neural network which outputs the class label the image belongs to.
# There are six class labels in our dataset: "buildings", "forests", "mountains", "glacier", "sea", and "street".
# In order to design and train your network, we provide a training set and validation set along with class labels for every image.
# As you are already familiar, we separate the dataset into three splits: training, validation, and testing.
# The train set has 6K images (1K per class), and the val and test sets each have 1.2K images (200 per class).
#
# An overview of the desired pipeline is shown in Figure.
#
#
# ![](https://docs.google.com/drawings/d/e/2PACX-1vRynZcZ1jfCu1GAsY9Hww68kr3iGaHj5XKeQptkF9lRysFpMtbbs4TZZaklAemoZJbMR-LUQnVkkI0b/pub?w=680&h=483 "Title")
#
#
# This exercise acts as a gentle introduction to [PyTorch](https://pytorch.org/), one of the most popular deep learning frameworks.
# We provide a majority of the code to get you started and familiarized with the framework.
# Running through all the cells will give you a simple linear network that can achieve the baseline performance.
# To pass, you will need to modify the given implementation and train a network that can achieve better performance.
#
# **Evaluation Criteria**
#
# Your algorithm will be evaluated using classification accuracy, which is the proportion of images with the correct predicted label.
# The final EvaluationScore is obtained as the classification accuracy over all test samples.
#
# **Passing requirement**
#
# Your algorithm will be evaluated on a test set. In order to pass the exercise, you need to obtain an EvaluationScore of **greater than $70.0$** on the test set.

# %% [markdown]
# ## Initialize the environment and load data
# Import the necessary libraries. Note that you are **NOT** allowed to use any additional libraries

# %%
# These two lines ensure that we always import the latest version of a package, in case it has been modified.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from matplotlib import pyplot as plt

import sys
import shutil
from pathlib import Path
import numpy as np

import torch
from torch.utils.data import DataLoader

#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# **TODO:** Set the path in Google drive where you uploaded the handout, e.g. My Drive/iacv/ex4

# %%
#iacv_path = '...' # TODO set this

# Add the handout folder to python paths
#env_path = Path('/content/drive') / iacv_path
env_path = Path(r"/home/simon/Downloads/ex4_cnn_classification/handout")
data_path = env_path / 'data'
if env_path not in sys.path:
    sys.path.append(str(env_path))

from utils import show_images

# %% [markdown]
# ## Overview
#
# In general, training any deep learning models consists of the following components
#
#
# *   **Dataset:** The data on which the model is trained. This could be e.g. large number of images, videos, text documents etc.
# *   **Model:** The network architecture we want to train. A significant part of developing deep learning solutions involves designing right architecture for a given problem.
# *   **Cost Function:** The criteria which is minimized over our dataset to train the network, e.g. Cross-entropy loss, Mean-squared error.
# *   **Optimizer:** The optimizer updates the model parameters to minimize the cost function. The most common example is Stochastic Gradient Descent. One also has to determine hyperparameters such as the learning rate, number of optimization iterations etc.
#
# As discussed in the lectures, the deep networks are trained using *mini-batches*, which are a set of training images (commonly between 8-128). Furthermore, data augmentation strategies (e.g. rotating an image) are commonly used to 'transform' the training images first, before passing it to a network. Thus, the data loading step itself can be broken down into following sub-steps,
# 1.   Load an image from the dataset. The images are randomly loaded from the dataset during training to avoid any bias.
# 2.   Apply necessary pre-processing to the image, e.g. remove mean, convert datatype to `float` etc.
# 3.   Apply desired data augmentations to the image, e.g. rotate an image, extract a random crop from the image.
# 4. Group a number of processed images to form a 'training batch'. This batch is then passed through the network to obtain predictions and compute loss.
#
#
#
#
# We will use the [PyTorch](https://pytorch.org/) deep learning framework to implement each of these components. Follow through the next cells to check the implementation.

# %% [markdown]
# ## Step 1: Data Loading
#
# We first take a look at how to define the datasets and data loading procedures in PyTorch.
#
# To do so, we need to create a PyTorch Dataset and DataLoader.
# The PyTorch Dataset handles loading the actual images and labels from file as well as applying any transformations on the loaded image. To define your own Dataset, you need to subclass the `torch.utils.data.Dataset` class and implement three functions:
#
# 1. `__init__`: Initialize the dataset.
# 2. `__len__`: Returns the number of samples in the dataset.
# 3. `__getitem__`: Given a specific index, load the corresponding images and labels and return them. Necessary transformations are commonly applied here, too.
#
# We have implemented a dataset class for our task.
# We have also implemented some basic transformations - you might want to add more augmentation strategies later.
# Please take a close look at the file `dataset.py` to see how it's done.

# %%
from dataset import ImageDataset
from transforms import get_transforms_train, get_transforms_val

# DataLoader for training data (Transforms include preprocessing + augmentation)
dataset_train = ImageDataset(data_path/'train.csv', data_path/'train.hdf5', get_transforms_train())

# DataLoader for validation data (Transforms include only preprocessing)
dataset_valid = ImageDataset(data_path/'val.csv', data_path/'val.hdf5', get_transforms_val())

# %% [markdown]
# Note that the PyTorch Dataset only deals with loading a single image at a time.
# The data sampling logic for loading multiple images is handled by the PyTorch DataLoader, which takes the Dataset as input and defines the logic for how to iterate over the entire dataset. To create the DataLoader, you need to use `torch.utils.data.DataLoader`, which has the following arguments:
#
# - `dataset`: A PyTorch Dataset.
# - `batch_size`: Number of images to load at a time.
# - `shuffle`: Whether to shuffle the dataset before loading the images. Usually, you will use shuffling during training and not during testing.
# - `num_workers`: Number of subprocesses to use for data loading.
# - ... and many more. You can find the full list [here](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader).
#
#
# We now create DataLoaders for our training and validation datasets.

# %%
batch_size = 8
num_workers = 12

# Generate our data loaders
train_loader = DataLoader(dataset_train, batch_size, shuffle=True, num_workers=num_workers)
valid_loader = DataLoader(dataset_valid, batch_size, shuffle=True, num_workers=num_workers)

# %% [markdown]
# Visualize a few training samples along with the ground truth labels to get an idea of how the images look. You can run this multiple times to check different images

# %%
# get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

show_images(images[:6], labels[:6])

# %% [markdown]
# ## Step 2: Define the Network
#
# After we've set up the data, we now need to define the network we will use to perform image classification.
#
# To do so, we need to create a PyTorch network.
# To define your own PyTorch network, you need to subclass the `torch.nn.Module` class and implement two functions:
#
# 1. `__init__`: Initialize the network, defining all the layers in the network to use.
# 2. `forward`: Defines the forward pass of the network, which takes an image as input and outputs classification scores for each class.
#
# As you will notice, we only have to define the forward pass of the network but not the backward pass (backpropagation). This is because PyTorch handles computing gradients for each operation for you ([autograd](https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html)), so you don't have to worry about it at all!
#
# We've implemented a very simple CNN for you already in `cnn_network.py` with a single convolutional layer, pooling layer, and fully-connected layer. You can run this cell to see the network architecture as well as test the forward pass of the network.
#
# **Important:** Don't forget to import the `cnn_network.py` file every time you modify it, otherwise your latest changes won't be loaded.

# %%
from cnn_network import CNN

cnn_network = CNN()  # create CNN model

print("CNN Architecture:")
print(cnn_network)

print("")
print("Testing network input / output.")
test_input = torch.zeros(1, 3, 50, 50)  # batch size X 3 (RGB) X width X height
print(f"Input shape: {test_input.shape}")
test_output = cnn_network(test_input)  # batch size X # classes
print(f"Output shape: {test_output.shape}")

assert tuple(test_output.shape) == (1, 6), "Output shape should be [1, 6]"
# Out:
# CNN Architecture:
# CNN(
#   (in_pipes): Sequential(
#     (0): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Conv2d(3, 15, kernel_size=(5, 5), stride=(1, 1))
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(15, 15, kernel_size=(5, 5), stride=(1, 1))
#     (5): Flatten(start_dim=1, end_dim=-1)
#   )
#   (out): Sequential(
#     (0): Linear(in_features=15, out_features=70, bias=False)
#     (1): ReLU()
#     (2): Linear(in_features=70, out_features=6, bias=False)
#   )
# )
#
# Testing network input / output.
# Input shape: torch.Size([1, 3, 50, 50])
# Output shape: torch.Size([1, 6])

# %% [markdown]
# ## Step 3: Define the cost function and the optimizer
#
# Next we define the cost function and the optimizer to be used for training.
#
# For the image classification task, the most commonly used loss function is the Cross-Entropy loss, which we will use here. However, feel free to play around with other losses you can think of.
#
# We will use the Stochastic-Gradient descent optimizer. The optimizer contains two hyperparameters, namely the learning rate and the momentum. You are free to test other optimizers. Note that PyTorch gives implementations of commonly used optimizers such as SGD, Adam, etc.
#
# Please check the `cnn_network.py` file to see how these components are defined.

# %%
from cnn_network import get_loss_function, get_optimizer

criterion = get_loss_function()  # get loss function
optimizer = get_optimizer(cnn_network, lr=0.001, momentum=0.9)  # get optimizer

# %% [markdown]
# ## Step 4: Train the Network
#
# Now that we've defined both the data and the network, it's time to train our network on the data.
#
# To do so, we simply just iterate over each batch of data, compute the network loss, then optimize the network parameters with backpropagation. See the code below for details on the right way to do this in PyTorch.
#
# Run this cell to train the network.
# This may take some time.
# You should see the training loss go down in the initial iterations then plateau.
#
# **Note:** We reinitialize the network, and load dataset, optimizer, loss function etc again here so that it is convenient to modify them in a single place.

# %%
from dataset import ImageDataset
from transforms import get_transforms_val, get_transforms_train
from cnn_network import CNN, get_loss_function, get_optimizer

# *********************************************************** #
# set all training parameters. You can play around with these
# *********************************************************** #

batch_size = 6           # Number of images in each batch
learning_rate = 1.1   # Learning rate in the optimizer
momentum = 0.9           # Momentum in SGD
num_epochs = 30           # Number of passes over the entire dataset
print_every_iters = 100  # Print training loss every X mini-batches

# *********************************************************** #
# Initialize all the training components, e.g. model, cost function
# *********************************************************** #

# Get transforms
transform_train = get_transforms_train()
transform_val = get_transforms_val()

# Generate our data loaders
dataset_train = ImageDataset(data_path/'train.csv', data_path/'train.hdf5', get_transforms_train())
dataset_valid = ImageDataset(data_path/'val.csv', data_path/'val.hdf5', get_transforms_val())

train_loader = DataLoader(dataset_train, batch_size, shuffle=True, num_workers=2)
valid_loader = DataLoader(dataset_valid, batch_size, shuffle=True, num_workers=2)

# create CNN model
cnn_network = CNN()

# Get optimizer and loss functions
criterion = get_loss_function()
optimizer = get_optimizer(cnn_network, lr=learning_rate, momentum=momentum)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, factor=0.5, patience=1, verbose=True)

# *********************************************************** #
# The main training loop. You dont need to change this
# *********************************************************** #
training_loss_per_epoch = []
val_loss_per_epoch = []
for epoch in range(num_epochs):  # loop over the dataset multiple times
    # First we loop over training dataset
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        # zero the parameter gradients
        optimizer.zero_grad()  # zero the gradients from previous iteration

        # forward + backward + optimize
        outputs = cnn_network(inputs)  # forward pass to obtain network outputs
        loss = criterion(outputs, labels)  # compute loss with respect to labels
        loss.backward()  # compute gradients with backpropagation (autograd)
        optimizer.step()  # optimize network parameters
        # print statistics
        running_loss += loss.item()
        if (i + 1) % print_every_iters == 0:
            print(
                f'[Epoch: {epoch + 1} / {num_epochs},'
                f' Iter: {i + 1:5d} / {len(train_loader)}]'
                f' Training loss: {running_loss / (i + 1):.3f}'
            )

    mean_loss = running_loss / len(train_loader)
    training_loss_per_epoch.append(mean_loss)

    # Next we loop over validation dataset
    running_loss = 0.0
    for i, data in enumerate(valid_loader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        # on validation dataset, we only do forward, without computing gradients
        with torch.inference_mode():
            outputs = cnn_network(inputs)  # forward pass to obtain network outputs
            loss = criterion(outputs, labels)  # compute loss with respect to labels

        # print statistics
        running_loss += loss.item()

    mean_loss = running_loss / len(valid_loader)
    val_loss_per_epoch.append(mean_loss)
    scheduler.step(mean_loss)


    print(
        f'[Epoch: {epoch + 1} / {num_epochs}]'
        f' Validation loss: {mean_loss:.3f}'
    )

print('Finished Training')

# Plot the training curves
plt.figure()
plt.plot(np.array(training_loss_per_epoch))
plt.plot(np.array(val_loss_per_epoch))
plt.legend(['Training loss', 'Val loss'])
plt.xlabel('Epoch')
plt.show()
plt.close()
# Out:
# [Epoch: 1 / 30, Iter:   100 / 1000] Training loss: 1.672
# [Epoch: 1 / 30, Iter:   200 / 1000] Training loss: 1.600
# [Epoch: 1 / 30, Iter:   300 / 1000] Training loss: 1.544
# [Epoch: 1 / 30, Iter:   400 / 1000] Training loss: 1.492
# [Epoch: 1 / 30, Iter:   500 / 1000] Training loss: 1.447
# [Epoch: 1 / 30, Iter:   600 / 1000] Training loss: 1.420
# [Epoch: 1 / 30, Iter:   700 / 1000] Training loss: 1.398
# [Epoch: 1 / 30, Iter:   800 / 1000] Training loss: 1.372
# [Epoch: 1 / 30, Iter:   900 / 1000] Training loss: 1.353
# [Epoch: 1 / 30, Iter:  1000 / 1000] Training loss: 1.338
# [Epoch: 1 / 30] Validation loss: 1.335
# [Epoch: 2 / 30, Iter:   100 / 1000] Training loss: 1.181
# [Epoch: 2 / 30, Iter:   200 / 1000] Training loss: 1.170
# [Epoch: 2 / 30, Iter:   300 / 1000] Training loss: 1.150
# [Epoch: 2 / 30, Iter:   400 / 1000] Training loss: 1.152
# [Epoch: 2 / 30, Iter:   500 / 1000] Training loss: 1.149
# [Epoch: 2 / 30, Iter:   600 / 1000] Training loss: 1.149
# [Epoch: 2 / 30, Iter:   700 / 1000] Training loss: 1.148
# [Epoch: 2 / 30, Iter:   800 / 1000] Training loss: 1.141
# [Epoch: 2 / 30, Iter:   900 / 1000] Training loss: 1.143
# [Epoch: 2 / 30, Iter:  1000 / 1000] Training loss: 1.137
# [Epoch: 2 / 30] Validation loss: 1.128
# [Epoch: 3 / 30, Iter:   100 / 1000] Training loss: 1.021
# [Epoch: 3 / 30, Iter:   200 / 1000] Training loss: 1.082
# [Epoch: 3 / 30, Iter:   300 / 1000] Training loss: 1.094
# [Epoch: 3 / 30, Iter:   400 / 1000] Training loss: 1.097
# [Epoch: 3 / 30, Iter:   500 / 1000] Training loss: 1.084
# [Epoch: 3 / 30, Iter:   600 / 1000] Training loss: 1.087
# [Epoch: 3 / 30, Iter:   700 / 1000] Training loss: 1.094
# [Epoch: 3 / 30, Iter:   800 / 1000] Training loss: 1.091
# [Epoch: 3 / 30, Iter:   900 / 1000] Training loss: 1.084
# [Epoch: 3 / 30, Iter:  1000 / 1000] Training loss: 1.080
# [Epoch: 3 / 30] Validation loss: 1.223
# [Epoch: 4 / 30, Iter:   100 / 1000] Training loss: 1.096
# [Epoch: 4 / 30, Iter:   200 / 1000] Training loss: 1.024
# [Epoch: 4 / 30, Iter:   300 / 1000] Training loss: 1.026
# [Epoch: 4 / 30, Iter:   400 / 1000] Training loss: 1.027
# [Epoch: 4 / 30, Iter:   500 / 1000] Training loss: 1.028
# [Epoch: 4 / 30, Iter:   600 / 1000] Training loss: 1.031
# [Epoch: 4 / 30, Iter:   700 / 1000] Training loss: 1.022
# [Epoch: 4 / 30, Iter:   800 / 1000] Training loss: 1.021
# [Epoch: 4 / 30, Iter:   900 / 1000] Training loss: 1.029
# [Epoch: 4 / 30, Iter:  1000 / 1000] Training loss: 1.032
# [Epoch: 4 / 30] Validation loss: 1.061
# [Epoch: 5 / 30, Iter:   100 / 1000] Training loss: 1.044
# [Epoch: 5 / 30, Iter:   200 / 1000] Training loss: 1.024
# [Epoch: 5 / 30, Iter:   300 / 1000] Training loss: 1.019
# [Epoch: 5 / 30, Iter:   400 / 1000] Training loss: 1.012
# [Epoch: 5 / 30, Iter:   500 / 1000] Training loss: 1.021
# [Epoch: 5 / 30, Iter:   600 / 1000] Training loss: 1.029
# [Epoch: 5 / 30, Iter:   700 / 1000] Training loss: 1.021
# [Epoch: 5 / 30, Iter:   800 / 1000] Training loss: 1.016
# [Epoch: 5 / 30, Iter:   900 / 1000] Training loss: 1.020
# [Epoch: 5 / 30, Iter:  1000 / 1000] Training loss: 1.021
# [Epoch: 5 / 30] Validation loss: 1.282
# [Epoch: 6 / 30, Iter:   100 / 1000] Training loss: 1.044
# [Epoch: 6 / 30, Iter:   200 / 1000] Training loss: 1.018
# [Epoch: 6 / 30, Iter:   300 / 1000] Training loss: 1.001
# [Epoch: 6 / 30, Iter:   400 / 1000] Training loss: 0.992
# [Epoch: 6 / 30, Iter:   500 / 1000] Training loss: 0.995
# [Epoch: 6 / 30, Iter:   600 / 1000] Training loss: 1.000
# [Epoch: 6 / 30, Iter:   700 / 1000] Training loss: 0.991
# [Epoch: 6 / 30, Iter:   800 / 1000] Training loss: 0.995
# [Epoch: 6 / 30, Iter:   900 / 1000] Training loss: 0.997
# [Epoch: 6 / 30, Iter:  1000 / 1000] Training loss: 0.996
# [Epoch: 6 / 30] Validation loss: 0.955
# [Epoch: 7 / 30, Iter:   100 / 1000] Training loss: 0.988
# [Epoch: 7 / 30, Iter:   200 / 1000] Training loss: 1.017
# [Epoch: 7 / 30, Iter:   300 / 1000] Training loss: 1.000
# [Epoch: 7 / 30, Iter:   400 / 1000] Training loss: 1.001
# [Epoch: 7 / 30, Iter:   500 / 1000] Training loss: 0.998
# [Epoch: 7 / 30, Iter:   600 / 1000] Training loss: 0.979
# [Epoch: 7 / 30, Iter:   700 / 1000] Training loss: 0.984
# [Epoch: 7 / 30, Iter:   800 / 1000] Training loss: 0.984
# [Epoch: 7 / 30, Iter:   900 / 1000] Training loss: 0.981
# [Epoch: 7 / 30, Iter:  1000 / 1000] Training loss: 0.982
# [Epoch: 7 / 30] Validation loss: 1.035
# [Epoch: 8 / 30, Iter:   100 / 1000] Training loss: 0.925
# [Epoch: 8 / 30, Iter:   200 / 1000] Training loss: 0.980
# [Epoch: 8 / 30, Iter:   300 / 1000] Training loss: 0.974
# [Epoch: 8 / 30, Iter:   400 / 1000] Training loss: 0.960
# [Epoch: 8 / 30, Iter:   500 / 1000] Training loss: 0.970
# [Epoch: 8 / 30, Iter:   600 / 1000] Training loss: 0.955
# [Epoch: 8 / 30, Iter:   700 / 1000] Training loss: 0.953
# [Epoch: 8 / 30, Iter:   800 / 1000] Training loss: 0.957
# [Epoch: 8 / 30, Iter:   900 / 1000] Training loss: 0.954
# [Epoch: 8 / 30, Iter:  1000 / 1000] Training loss: 0.956
# Epoch 00008: reducing learning rate of group 0 to 5.5000e-01.
# [Epoch: 8 / 30] Validation loss: 0.972
# [Epoch: 9 / 30, Iter:   100 / 1000] Training loss: 0.842
# [Epoch: 9 / 30, Iter:   200 / 1000] Training loss: 0.841
# [Epoch: 9 / 30, Iter:   300 / 1000] Training loss: 0.830
# [Epoch: 9 / 30, Iter:   400 / 1000] Training loss: 0.823
# [Epoch: 9 / 30, Iter:   500 / 1000] Training loss: 0.831
# [Epoch: 9 / 30, Iter:   600 / 1000] Training loss: 0.842
# [Epoch: 9 / 30, Iter:   700 / 1000] Training loss: 0.849
# [Epoch: 9 / 30, Iter:   800 / 1000] Training loss: 0.851
# [Epoch: 9 / 30, Iter:   900 / 1000] Training loss: 0.854
# [Epoch: 9 / 30, Iter:  1000 / 1000] Training loss: 0.845
# [Epoch: 9 / 30] Validation loss: 0.953
# [Epoch: 10 / 30, Iter:   100 / 1000] Training loss: 0.840
# [Epoch: 10 / 30, Iter:   200 / 1000] Training loss: 0.849
# [Epoch: 10 / 30, Iter:   300 / 1000] Training loss: 0.836
# [Epoch: 10 / 30, Iter:   400 / 1000] Training loss: 0.835
# [Epoch: 10 / 30, Iter:   500 / 1000] Training loss: 0.844
# [Epoch: 10 / 30, Iter:   600 / 1000] Training loss: 0.833
# [Epoch: 10 / 30, Iter:   700 / 1000] Training loss: 0.819
# [Epoch: 10 / 30, Iter:   800 / 1000] Training loss: 0.818
# [Epoch: 10 / 30, Iter:   900 / 1000] Training loss: 0.824
# [Epoch: 10 / 30, Iter:  1000 / 1000] Training loss: 0.828
# [Epoch: 10 / 30] Validation loss: 0.939
# [Epoch: 11 / 30, Iter:   100 / 1000] Training loss: 0.799
# [Epoch: 11 / 30, Iter:   200 / 1000] Training loss: 0.795
# [Epoch: 11 / 30, Iter:   300 / 1000] Training loss: 0.807
# [Epoch: 11 / 30, Iter:   400 / 1000] Training loss: 0.814
# [Epoch: 11 / 30, Iter:   500 / 1000] Training loss: 0.817
# [Epoch: 11 / 30, Iter:   600 / 1000] Training loss: 0.811
# [Epoch: 11 / 30, Iter:   700 / 1000] Training loss: 0.816
# [Epoch: 11 / 30, Iter:   800 / 1000] Training loss: 0.818
# [Epoch: 11 / 30, Iter:   900 / 1000] Training loss: 0.828
# [Epoch: 11 / 30, Iter:  1000 / 1000] Training loss: 0.828
# [Epoch: 11 / 30] Validation loss: 0.935
# [Epoch: 12 / 30, Iter:   100 / 1000] Training loss: 0.757
# [Epoch: 12 / 30, Iter:   200 / 1000] Training loss: 0.798
# [Epoch: 12 / 30, Iter:   300 / 1000] Training loss: 0.809
# [Epoch: 12 / 30, Iter:   400 / 1000] Training loss: 0.811
# [Epoch: 12 / 30, Iter:   500 / 1000] Training loss: 0.803
# [Epoch: 12 / 30, Iter:   600 / 1000] Training loss: 0.812
# [Epoch: 12 / 30, Iter:   700 / 1000] Training loss: 0.808
# [Epoch: 12 / 30, Iter:   800 / 1000] Training loss: 0.815
# [Epoch: 12 / 30, Iter:   900 / 1000] Training loss: 0.815
# [Epoch: 12 / 30, Iter:  1000 / 1000] Training loss: 0.816
# [Epoch: 12 / 30] Validation loss: 0.897
# [Epoch: 13 / 30, Iter:   100 / 1000] Training loss: 0.795
# [Epoch: 13 / 30, Iter:   200 / 1000] Training loss: 0.789
# [Epoch: 13 / 30, Iter:   300 / 1000] Training loss: 0.798
# [Epoch: 13 / 30, Iter:   400 / 1000] Training loss: 0.801
# [Epoch: 13 / 30, Iter:   500 / 1000] Training loss: 0.806
# [Epoch: 13 / 30, Iter:   600 / 1000] Training loss: 0.806
# [Epoch: 13 / 30, Iter:   700 / 1000] Training loss: 0.813
# [Epoch: 13 / 30, Iter:   800 / 1000] Training loss: 0.817
# [Epoch: 13 / 30, Iter:   900 / 1000] Training loss: 0.816
# [Epoch: 13 / 30, Iter:  1000 / 1000] Training loss: 0.819
# [Epoch: 13 / 30] Validation loss: 0.859
# [Epoch: 14 / 30, Iter:   100 / 1000] Training loss: 0.774
# [Epoch: 14 / 30, Iter:   200 / 1000] Training loss: 0.772
# [Epoch: 14 / 30, Iter:   300 / 1000] Training loss: 0.763
# [Epoch: 14 / 30, Iter:   400 / 1000] Training loss: 0.792
# [Epoch: 14 / 30, Iter:   500 / 1000] Training loss: 0.798
# [Epoch: 14 / 30, Iter:   600 / 1000] Training loss: 0.792
# [Epoch: 14 / 30, Iter:   700 / 1000] Training loss: 0.806
# [Epoch: 14 / 30, Iter:   800 / 1000] Training loss: 0.811
# [Epoch: 14 / 30, Iter:   900 / 1000] Training loss: 0.804
# [Epoch: 14 / 30, Iter:  1000 / 1000] Training loss: 0.801
# [Epoch: 14 / 30] Validation loss: 0.894
# [Epoch: 15 / 30, Iter:   100 / 1000] Training loss: 0.730
# [Epoch: 15 / 30, Iter:   200 / 1000] Training loss: 0.776
# [Epoch: 15 / 30, Iter:   300 / 1000] Training loss: 0.772
# [Epoch: 15 / 30, Iter:   400 / 1000] Training loss: 0.773
# [Epoch: 15 / 30, Iter:   500 / 1000] Training loss: 0.790
# [Epoch: 15 / 30, Iter:   600 / 1000] Training loss: 0.801
# [Epoch: 15 / 30, Iter:   700 / 1000] Training loss: 0.799
# [Epoch: 15 / 30, Iter:   800 / 1000] Training loss: 0.801
# [Epoch: 15 / 30, Iter:   900 / 1000] Training loss: 0.801
# [Epoch: 15 / 30, Iter:  1000 / 1000] Training loss: 0.802
# Epoch 00015: reducing learning rate of group 0 to 2.7500e-01.
# [Epoch: 15 / 30] Validation loss: 0.923
# [Epoch: 16 / 30, Iter:   100 / 1000] Training loss: 0.749
# [Epoch: 16 / 30, Iter:   200 / 1000] Training loss: 0.721
# [Epoch: 16 / 30, Iter:   300 / 1000] Training loss: 0.721
# [Epoch: 16 / 30, Iter:   400 / 1000] Training loss: 0.759
# [Epoch: 16 / 30, Iter:   500 / 1000] Training loss: 0.754
# [Epoch: 16 / 30, Iter:   600 / 1000] Training loss: 0.754
# [Epoch: 16 / 30, Iter:   700 / 1000] Training loss: 0.749
# [Epoch: 16 / 30, Iter:   800 / 1000] Training loss: 0.746
# [Epoch: 16 / 30, Iter:   900 / 1000] Training loss: 0.741
# [Epoch: 16 / 30, Iter:  1000 / 1000] Training loss: 0.741
# [Epoch: 16 / 30] Validation loss: 0.844
# [Epoch: 17 / 30, Iter:   100 / 1000] Training loss: 0.662
# [Epoch: 17 / 30, Iter:   200 / 1000] Training loss: 0.698
# [Epoch: 17 / 30, Iter:   300 / 1000] Training loss: 0.692
# [Epoch: 17 / 30, Iter:   400 / 1000] Training loss: 0.719
# [Epoch: 17 / 30, Iter:   500 / 1000] Training loss: 0.725
# [Epoch: 17 / 30, Iter:   600 / 1000] Training loss: 0.724
# [Epoch: 17 / 30, Iter:   700 / 1000] Training loss: 0.718
# [Epoch: 17 / 30, Iter:   800 / 1000] Training loss: 0.722
# [Epoch: 17 / 30, Iter:   900 / 1000] Training loss: 0.729
# [Epoch: 17 / 30, Iter:  1000 / 1000] Training loss: 0.730
# [Epoch: 17 / 30] Validation loss: 0.866
# [Epoch: 18 / 30, Iter:   100 / 1000] Training loss: 0.724
# [Epoch: 18 / 30, Iter:   200 / 1000] Training loss: 0.745
# [Epoch: 18 / 30, Iter:   300 / 1000] Training loss: 0.733
# [Epoch: 18 / 30, Iter:   400 / 1000] Training loss: 0.740
# [Epoch: 18 / 30, Iter:   500 / 1000] Training loss: 0.735
# [Epoch: 18 / 30, Iter:   600 / 1000] Training loss: 0.735
# [Epoch: 18 / 30, Iter:   700 / 1000] Training loss: 0.744
# [Epoch: 18 / 30, Iter:   800 / 1000] Training loss: 0.742
# [Epoch: 18 / 30, Iter:   900 / 1000] Training loss: 0.741
# [Epoch: 18 / 30, Iter:  1000 / 1000] Training loss: 0.731
# Epoch 00018: reducing learning rate of group 0 to 1.3750e-01.
# [Epoch: 18 / 30] Validation loss: 0.918
# [Epoch: 19 / 30, Iter:   100 / 1000] Training loss: 0.709
# [Epoch: 19 / 30, Iter:   200 / 1000] Training loss: 0.700
# [Epoch: 19 / 30, Iter:   300 / 1000] Training loss: 0.696
# [Epoch: 19 / 30, Iter:   400 / 1000] Training loss: 0.696
# [Epoch: 19 / 30, Iter:   500 / 1000] Training loss: 0.693
# [Epoch: 19 / 30, Iter:   600 / 1000] Training loss: 0.685
# [Epoch: 19 / 30, Iter:   700 / 1000] Training loss: 0.683
# [Epoch: 19 / 30, Iter:   800 / 1000] Training loss: 0.693
# [Epoch: 19 / 30, Iter:   900 / 1000] Training loss: 0.695
# [Epoch: 19 / 30, Iter:  1000 / 1000] Training loss: 0.700
# [Epoch: 19 / 30] Validation loss: 0.808
# [Epoch: 20 / 30, Iter:   100 / 1000] Training loss: 0.607
# [Epoch: 20 / 30, Iter:   200 / 1000] Training loss: 0.658
# [Epoch: 20 / 30, Iter:   300 / 1000] Training loss: 0.665
# [Epoch: 20 / 30, Iter:   400 / 1000] Training loss: 0.671
# [Epoch: 20 / 30, Iter:   500 / 1000] Training loss: 0.683
# [Epoch: 20 / 30, Iter:   600 / 1000] Training loss: 0.685
# [Epoch: 20 / 30, Iter:   700 / 1000] Training loss: 0.689
# [Epoch: 20 / 30, Iter:   800 / 1000] Training loss: 0.684
# [Epoch: 20 / 30, Iter:   900 / 1000] Training loss: 0.681
# [Epoch: 20 / 30, Iter:  1000 / 1000] Training loss: 0.684
# [Epoch: 20 / 30] Validation loss: 0.817
# [Epoch: 21 / 30, Iter:   100 / 1000] Training loss: 0.701
# [Epoch: 21 / 30, Iter:   200 / 1000] Training loss: 0.722
# [Epoch: 21 / 30, Iter:   300 / 1000] Training loss: 0.697
# [Epoch: 21 / 30, Iter:   400 / 1000] Training loss: 0.685
# [Epoch: 21 / 30, Iter:   500 / 1000] Training loss: 0.691
# [Epoch: 21 / 30, Iter:   600 / 1000] Training loss: 0.689
# [Epoch: 21 / 30, Iter:   700 / 1000] Training loss: 0.691
# [Epoch: 21 / 30, Iter:   800 / 1000] Training loss: 0.690
# [Epoch: 21 / 30, Iter:   900 / 1000] Training loss: 0.686
# [Epoch: 21 / 30, Iter:  1000 / 1000] Training loss: 0.683
# Epoch 00021: reducing learning rate of group 0 to 6.8750e-02.
# [Epoch: 21 / 30] Validation loss: 0.814
# [Epoch: 22 / 30, Iter:   100 / 1000] Training loss: 0.615
# [Epoch: 22 / 30, Iter:   200 / 1000] Training loss: 0.650
# [Epoch: 22 / 30, Iter:   300 / 1000] Training loss: 0.666
# [Epoch: 22 / 30, Iter:   400 / 1000] Training loss: 0.659
# [Epoch: 22 / 30, Iter:   500 / 1000] Training loss: 0.652
# [Epoch: 22 / 30, Iter:   600 / 1000] Training loss: 0.666
# [Epoch: 22 / 30, Iter:   700 / 1000] Training loss: 0.661
# [Epoch: 22 / 30, Iter:   800 / 1000] Training loss: 0.670
# [Epoch: 22 / 30, Iter:   900 / 1000] Training loss: 0.672
# [Epoch: 22 / 30, Iter:  1000 / 1000] Training loss: 0.667
# [Epoch: 22 / 30] Validation loss: 0.816
# [Epoch: 23 / 30, Iter:   100 / 1000] Training loss: 0.634
# [Epoch: 23 / 30, Iter:   200 / 1000] Training loss: 0.651
# [Epoch: 23 / 30, Iter:   300 / 1000] Training loss: 0.664
# [Epoch: 23 / 30, Iter:   400 / 1000] Training loss: 0.667
# [Epoch: 23 / 30, Iter:   500 / 1000] Training loss: 0.664
# [Epoch: 23 / 30, Iter:   600 / 1000] Training loss: 0.668
# [Epoch: 23 / 30, Iter:   700 / 1000] Training loss: 0.666
# [Epoch: 23 / 30, Iter:   800 / 1000] Training loss: 0.663
# [Epoch: 23 / 30, Iter:   900 / 1000] Training loss: 0.661
# [Epoch: 23 / 30, Iter:  1000 / 1000] Training loss: 0.667
# Epoch 00023: reducing learning rate of group 0 to 3.4375e-02.
# [Epoch: 23 / 30] Validation loss: 0.821
# [Epoch: 24 / 30, Iter:   100 / 1000] Training loss: 0.680
# [Epoch: 24 / 30, Iter:   200 / 1000] Training loss: 0.643
# [Epoch: 24 / 30, Iter:   300 / 1000] Training loss: 0.640
# [Epoch: 24 / 30, Iter:   400 / 1000] Training loss: 0.641
# [Epoch: 24 / 30, Iter:   500 / 1000] Training loss: 0.642
# [Epoch: 24 / 30, Iter:   600 / 1000] Training loss: 0.643
# [Epoch: 24 / 30, Iter:   700 / 1000] Training loss: 0.655
# [Epoch: 24 / 30, Iter:   800 / 1000] Training loss: 0.651
# [Epoch: 24 / 30, Iter:   900 / 1000] Training loss: 0.652
# [Epoch: 24 / 30, Iter:  1000 / 1000] Training loss: 0.648
# [Epoch: 24 / 30] Validation loss: 0.806
# [Epoch: 25 / 30, Iter:   100 / 1000] Training loss: 0.667
# [Epoch: 25 / 30, Iter:   200 / 1000] Training loss: 0.615
# [Epoch: 25 / 30, Iter:   300 / 1000] Training loss: 0.633
# [Epoch: 25 / 30, Iter:   400 / 1000] Training loss: 0.630
# [Epoch: 25 / 30, Iter:   500 / 1000] Training loss: 0.629
# [Epoch: 25 / 30, Iter:   600 / 1000] Training loss: 0.628
# [Epoch: 25 / 30, Iter:   700 / 1000] Training loss: 0.633
# [Epoch: 25 / 30, Iter:   800 / 1000] Training loss: 0.639
# [Epoch: 25 / 30, Iter:   900 / 1000] Training loss: 0.646
# [Epoch: 25 / 30, Iter:  1000 / 1000] Training loss: 0.654
# [Epoch: 25 / 30] Validation loss: 0.815
# [Epoch: 26 / 30, Iter:   100 / 1000] Training loss: 0.642
# [Epoch: 26 / 30, Iter:   200 / 1000] Training loss: 0.635
# [Epoch: 26 / 30, Iter:   300 / 1000] Training loss: 0.631
# [Epoch: 26 / 30, Iter:   400 / 1000] Training loss: 0.659
# [Epoch: 26 / 30, Iter:   500 / 1000] Training loss: 0.645
# [Epoch: 26 / 30, Iter:   600 / 1000] Training loss: 0.662
# [Epoch: 26 / 30, Iter:   700 / 1000] Training loss: 0.659
# [Epoch: 26 / 30, Iter:   800 / 1000] Training loss: 0.657
# [Epoch: 26 / 30, Iter:   900 / 1000] Training loss: 0.654
# [Epoch: 26 / 30, Iter:  1000 / 1000] Training loss: 0.648
# Epoch 00026: reducing learning rate of group 0 to 1.7188e-02.
# [Epoch: 26 / 30] Validation loss: 0.819
# [Epoch: 27 / 30, Iter:   100 / 1000] Training loss: 0.689
# [Epoch: 27 / 30, Iter:   200 / 1000] Training loss: 0.662
# [Epoch: 27 / 30, Iter:   300 / 1000] Training loss: 0.670
# [Epoch: 27 / 30, Iter:   400 / 1000] Training loss: 0.666
# [Epoch: 27 / 30, Iter:   500 / 1000] Training loss: 0.664
# [Epoch: 27 / 30, Iter:   600 / 1000] Training loss: 0.659
# [Epoch: 27 / 30, Iter:   700 / 1000] Training loss: 0.655
# [Epoch: 27 / 30, Iter:   800 / 1000] Training loss: 0.651
# [Epoch: 27 / 30, Iter:   900 / 1000] Training loss: 0.644
# [Epoch: 27 / 30, Iter:  1000 / 1000] Training loss: 0.642
# [Epoch: 27 / 30] Validation loss: 0.812
# [Epoch: 28 / 30, Iter:   100 / 1000] Training loss: 0.662
# [Epoch: 28 / 30, Iter:   200 / 1000] Training loss: 0.624
# [Epoch: 28 / 30, Iter:   300 / 1000] Training loss: 0.634
# [Epoch: 28 / 30, Iter:   400 / 1000] Training loss: 0.643
# [Epoch: 28 / 30, Iter:   500 / 1000] Training loss: 0.637
# [Epoch: 28 / 30, Iter:   600 / 1000] Training loss: 0.635
# [Epoch: 28 / 30, Iter:   700 / 1000] Training loss: 0.637
# [Epoch: 28 / 30, Iter:   800 / 1000] Training loss: 0.639
# [Epoch: 28 / 30, Iter:   900 / 1000] Training loss: 0.640
# [Epoch: 28 / 30, Iter:  1000 / 1000] Training loss: 0.647
# [Epoch: 28 / 30] Validation loss: 0.799
# [Epoch: 29 / 30, Iter:   100 / 1000] Training loss: 0.669
# [Epoch: 29 / 30, Iter:   200 / 1000] Training loss: 0.628
# [Epoch: 29 / 30, Iter:   300 / 1000] Training loss: 0.621
# [Epoch: 29 / 30, Iter:   400 / 1000] Training loss: 0.640
# [Epoch: 29 / 30, Iter:   500 / 1000] Training loss: 0.645
# [Epoch: 29 / 30, Iter:   600 / 1000] Training loss: 0.647
# [Epoch: 29 / 30, Iter:   700 / 1000] Training loss: 0.651
# [Epoch: 29 / 30, Iter:   800 / 1000] Training loss: 0.647
# [Epoch: 29 / 30, Iter:   900 / 1000] Training loss: 0.650
# [Epoch: 29 / 30, Iter:  1000 / 1000] Training loss: 0.646
# [Epoch: 29 / 30] Validation loss: 0.795
# [Epoch: 30 / 30, Iter:   100 / 1000] Training loss: 0.648
# [Epoch: 30 / 30, Iter:   200 / 1000] Training loss: 0.650
# [Epoch: 30 / 30, Iter:   300 / 1000] Training loss: 0.651
# [Epoch: 30 / 30, Iter:   400 / 1000] Training loss: 0.644
# [Epoch: 30 / 30, Iter:   500 / 1000] Training loss: 0.658
# [Epoch: 30 / 30, Iter:   600 / 1000] Training loss: 0.658
# [Epoch: 30 / 30, Iter:   700 / 1000] Training loss: 0.648
# [Epoch: 30 / 30, Iter:   800 / 1000] Training loss: 0.644
# [Epoch: 30 / 30, Iter:   900 / 1000] Training loss: 0.648
# [Epoch: 30 / 30, Iter:  1000 / 1000] Training loss: 0.644
# [Epoch: 30 / 30] Validation loss: 0.811
# Finished Training

# %% [markdown]
# ## Step 5: Test the Network
#
# After training the network, it is time to test our network on the validation set, which includes images not seen during training. This will tell us how well the network can perform on new data.
#
# We first visualize several network predictions on validation samples along with the ground truth labels.
# You can run this cell multiple times to visualize different images.

# %%
# get a few validation samples
images, labels = next(iter(valid_loader))

with torch.inference_mode():
# get network output:
	outputs = cnn_network(images)  # classification scores
	_, predicted = torch.max(outputs, 1)  # use maximum as prediction label

# visualize ground truth and predictions
show_images(images[:4], labels[:4], predicted[:4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/user/ex4/handout/handout.ipynb Cell 20 line 2
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a6f6c6c795f6e6170696572222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/user/ex4/handout/handout.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # get a few validation samples
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a6f6c6c795f6e6170696572222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/user/ex4/handout/handout.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> images, labels = next(iter(valid_loader))
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a6f6c6c795f6e6170696572222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/user/ex4/handout/handout.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> with torch.inference_mode():
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a6f6c6c795f6e6170696572222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/user/ex4/handout/handout.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> # get network output:
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a6f6c6c795f6e6170696572222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/user/ex4/handout/handout.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> 	outputs = cnn_network(images)  # classification scores
#
# NameError: name 'valid_loader' is not defined

# %% [markdown]
# To get the full picture of the network performance, we need to evaluate on the full validation set.
# This cell will iterate over every validation image, obtain the network prediction, and compare with the corresponding ground truth.
# The evaluation score is the percentage of labels predicted correctly.
# This may take some time.
# You should see an accuracy of around 63%.

# %%
from utils import compute_accuracy

with torch.inference_mode():
	acc = compute_accuracy(cnn_network, valid_loader)
print(f'Accuracy of the network on the 1500 validation images: {acc:.2f} %')
# Out:
# Accuracy of the network on the 1500 validation images: 72.92 %

# %% [markdown]
# ## Your Turn
#
# **TODO:** We provided a simple CNN and boilerplate training code to introduce PyTorch to you.
# These are written in their simplest form to leave ample room for extension.
# Your task is to improve the network's performance on the test set.
#
# **Note:** You are not allowed to use any external packages except the ones already imported in `cnn_network.py`. Otherwise your submission will crash on the Evaluation server.
#
#
# **Hints:** Things that can potentially improve test accuracy:
# - Deeper architecture: Adding more layers can lead to better performance, but be careful of overfitting to the training set!
# - Activation functions: Introducing activation functions can increase the capacity of the network.
# - Training parameters: Modifying the length of training, learning rate, optimizer, loss function, etc. can all improve network performance, but again be careful of overfitting!
# - Transforms: Adding data transforms essentially generates more data for training, which helps alleviate overfitting. See full list of available transforms [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ## Generate the final submission on the test set
#
# When you are happy with your network, you can run the next cell to generate your submission.
# We will copy the relevant files, as well as save the learned model parameters to the submission folder.
# As usual, download the submission folder (**without renaming**) as a zip, and upload it to the evaluation server. There your code will run to predict the test image labels.

# %%
out_dir = env_path / 'submission'
out_dir.mkdir(exist_ok=True)

cnn_network.write_weights(out_dir / 'checkpoint.pt')
shutil.copyfile(env_path / 'cnn_network.py', out_dir / 'cnn_network.py')
shutil.copyfile(env_path / 'transforms.py', out_dir / 'transforms.py')

print("Done. You can submit now.")
# Out:
# Done. You can submit now.

# %%
# Out:
# Running cells with '2023.2.0' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n 2023.2.0 ipykernel --update-deps --force-reinstall'
